# %% [markdown]
# ### Ryeol try Preprocessing the NA Value
# ### 2022 - 07 - 29
# ### Python kernel : pycaret(Python 3.8.13)

# %%
from pycaret.regression import *
import pandas as pd

# %%
df = pd.read_csv("C:/Everydata/competition_data/water_data/data_2012.csv", index_col = 0)
df
# Out:
#                      swl    inf     sfw   ecpc  tototf  tide_level  \
# ymdhm
# 2012-05-01 0:00   24.800  555.0  219.07  24.93   555.0       445.0
# 2012-05-01 0:10   24.794  464.6  218.86  25.15   562.9       449.0
# 2012-05-01 0:20   24.789  478.1  218.69  25.31   576.4       451.0
# 2012-05-01 0:30   24.789  464.8  218.69  25.31   563.1       452.0
# 2012-05-01 0:40   24.789  478.1  218.69  25.31   576.4       450.0
# ...                  ...    ...     ...    ...     ...         ...
# 2012-10-31 23:10  25.250  270.2  235.01   8.99   270.2       300.0
# 2012-10-31 23:20  25.250  264.1  235.01   8.99   264.1       286.0
# 2012-10-31 23:30  25.250  257.9  235.01   8.99   257.9       273.0
# 2012-10-31 23:40  25.250  264.1  235.01   8.99   264.1       261.0
# 2012-10-31 23:50  25.250  270.2  235.03   8.97   270.2       249.0
#
#                   wl_1018662  fw_1018662  wl_1018680  fw_1018680  wl_1018683  \
# ymdhm
# ...

# %%
reg_test_1 = setup(data= df, target='wl_1018662', train_size=0.7, fold=5)
# Out:
# <style type="text/css">
# #T_eb44e_row3_col1, #T_eb44e_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_eb44e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb44e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_eb44e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb44e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb44e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_eb44e_row0_col1" class="data row0 col1" >6545</td>
#     </tr>
#     <tr>
#       <th id="T_eb44e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb44e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_eb44e_row1_col1" class="data row1 col1" >wl_1018662</td>
#     </tr>
#     <tr>
#       <th id="T_eb44e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models(sort='mse')
# Out:
# <style type="text/css">
# #T_91d1d th {
#   text-align: left;
# }
# ...

# %%
best
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=6545, verbose=0, warm_start=False)

# %%
best_tune
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000007untitled?line=0'>1</a> best_tune
#
# NameError: name 'best_tune' is not defined

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_461a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_461a7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_461a7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_461a7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_461a7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_461a7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_461a7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_461a7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_461a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_461a7_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_461a7_row0_col1" class="data row0 col1" >0.0258</td>
# ...

# %%
df1 = pd.read_csv('C:/Users/82108/Downloads/전체데이터/Features/data1.csv', encoding = 'UTF-8', index_col = 0)
# Out:
# Failed to start the Kernel.
#
# Canceled.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
